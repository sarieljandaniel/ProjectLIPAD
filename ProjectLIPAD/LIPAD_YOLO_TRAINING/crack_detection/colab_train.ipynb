# %% [markdown]
# # LiPAD — Crack Detection (YOLOv8 / v11 / v12)
#
# Train segmentation models for **structural crack** detection.
#
# - **Cursor:** Open this `.ipynb` and run cells (install Jupyter extension if prompted).
# - **Google Colab:** Upload this folder → **Runtime → Change runtime type → GPU**.

# %%
# @title Environment setup
import sys
from pathlib import Path

IN_COLAB = False
try:
    import google.colab
    IN_COLAB = True
except ImportError:
    pass

if IN_COLAB:
    from google.colab import drive
    drive.mount('/content/drive')
    # %cd /content
else:
    ROOT = Path(r'C:/Users/ADMIN/PROJECT_LIPAD_ANALYSIS/LIPAD_YOLO_TRAINING')
    if (Path.cwd() / 'shared').exists():
        ROOT = Path.cwd()
    elif (Path.cwd().parent / 'shared').exists():
        ROOT = Path.cwd().parent
    # %cd {ROOT}
    sys.path.insert(0, str(ROOT))
    print('Repo root:', ROOT)

# !pip install -q -U ultralytics torch torchvision pyyaml

# %%
# @title Verify dataset layout
from shared.paths import ensure_dataset_layout, datasets_dir

ensure_dataset_layout('crack_detection')
print('Dataset folder:', datasets_dir('crack_detection'))

# %%
# @title Train YOLOv8
from shared.trainer import train
train('crack', 'yolov8', epochs=100, imgsz=640, batch=16 if IN_COLAB else 8)

# %%
# @title Train YOLOv11
from shared.trainer import train
train('crack', 'yolov11', epochs=100, imgsz=640, batch=16 if IN_COLAB else 8)

# %%
# @title Train YOLOv12
from shared.trainer import train
train('crack', 'yolov12', epochs=100, imgsz=640, batch=16 if IN_COLAB else 8)
